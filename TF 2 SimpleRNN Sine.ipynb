# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.8.0'

# %%
from tensorflow.keras.layers import Input, SimpleRNN, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Membuat data
series = np.sin(0.1*np.arange(200)) + np.random.randn(200)* 0.1

#plot data
plt.plot(series)
plt.show()

# %%
# Membuat dataset
T = 10
X = []
Y = []
for t in range(len(series) - T):
    x = series[t:t+T]
    X.append(x)
    y = series[t+T]
    Y.append(y)

X = np.array(X).reshape(-1, T)
Y = np.array(Y)
N = len(X)
print("X.shape: ", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape:  (190, 10) Y.shape (190,)

# %%
### menggunakan model autoregressive
i = Input(shape=(T, 1))
x = SimpleRNN(5, activation='relu')(i)
x = Dense(1)(x)
model = Model(i, x)
model.compile(
    loss='mse',
    optimizer=Adam(lr=0.1),
)

# Training RNN
train = model.fit(
    X[:-N//2], Y[:-N//2],
    epochs=80,
    validation_data=(X[-N//2:], Y[-N//2:])
)
# Out:
# Epoch 1/80
# C:\Users\ydhi\AppData\Roaming\Python\Python38\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 3/3 [==============================] - 2s 293ms/step - loss: 0.2333 - val_loss: 0.0878
# Epoch 2/80
# 3/3 [==============================] - 0s 132ms/step - loss: 0.0776 - val_loss: 0.0355
# Epoch 3/80
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0472 - val_loss: 0.0331
# Epoch 4/80
# 3/3 [==============================] - 0s 120ms/step - loss: 0.0364 - val_loss: 0.0262
# Epoch 5/80
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0240 - val_loss: 0.0286
# Epoch 6/80
# 3/3 [==============================] - 0s 137ms/step - loss: 0.0288 - val_loss: 0.0309
# Epoch 7/80
# 3/3 [==============================] - 0s 139ms/step - loss: 0.0316 - val_loss: 0.0276
# Epoch 8/80
# 3/3 [==============================] - 0s 132ms/step - loss: 0.0272 - val_loss: 0.0241
# Epoch 9/80
# 3/3 [==============================] - 0s 134ms/step - loss: 0.0234 - val_loss: 0.0230
# Epoch 10/80
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0266 - val_loss: 0.0246
# Epoch 11/80
# 3/3 [==============================] - 0s 131ms/step - loss: 0.0271 - val_loss: 0.0228
# Epoch 12/80
# 3/3 [==============================] - 0s 144ms/step - loss: 0.0252 - val_loss: 0.0217
# Epoch 13/80
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0244 - val_loss: 0.0219
# Epoch 14/80
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0230 - val_loss: 0.0276
# Epoch 15/80
# 3/3 [==============================] - 0s 132ms/step - loss: 0.0253 - val_loss: 0.0254
# Epoch 16/80
# 3/3 [==============================] - 0s 145ms/step - loss: 0.0267 - val_loss: 0.0298
# Epoch 17/80
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0266 - val_loss: 0.0224
# Epoch 18/80
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0258 - val_loss: 0.0257
# Epoch 19/80
# 3/3 [==============================] - 0s 151ms/step - loss: 0.0235 - val_loss: 0.0222
# Epoch 20/80
# 3/3 [==============================] - 0s 151ms/step - loss: 0.0250 - val_loss: 0.0234
# Epoch 21/80
# 3/3 [==============================] - 0s 135ms/step - loss: 0.0228 - val_loss: 0.0199
# Epoch 22/80
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0229 - val_loss: 0.0231
# Epoch 23/80
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0228 - val_loss: 0.0203
# Epoch 24/80
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0222 - val_loss: 0.0201
# Epoch 25/80
# 3/3 [==============================] - 0s 140ms/step - loss: 0.0238 - val_loss: 0.0225
# Epoch 26/80
# 3/3 [==============================] - 0s 133ms/step - loss: 0.0244 - val_loss: 0.0202
# Epoch 27/80
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0223 - val_loss: 0.0197
# Epoch 28/80
# 3/3 [==============================] - 0s 140ms/step - loss: 0.0238 - val_loss: 0.0211
# Epoch 29/80
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0223 - val_loss: 0.0198
# Epoch 30/80
# 3/3 [==============================] - 0s 140ms/step - loss: 0.0230 - val_loss: 0.0246
# Epoch 31/80
# 3/3 [==============================] - 0s 138ms/step - loss: 0.0255 - val_loss: 0.0198
# Epoch 32/80
# 3/3 [==============================] - 0s 133ms/step - loss: 0.0227 - val_loss: 0.0201
# Epoch 33/80
# 3/3 [==============================] - 0s 142ms/step - loss: 0.0231 - val_loss: 0.0208
# Epoch 34/80
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0216 - val_loss: 0.0198
# Epoch 35/80
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0221 - val_loss: 0.0214
# Epoch 36/80
# 3/3 [==============================] - 0s 138ms/step - loss: 0.0222 - val_loss: 0.0205
# Epoch 37/80
# 3/3 [==============================] - 0s 149ms/step - loss: 0.0214 - val_loss: 0.0208
# Epoch 38/80
# 3/3 [==============================] - 0s 121ms/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 39/80
# 3/3 [==============================] - 0s 141ms/step - loss: 0.0214 - val_loss: 0.0207
# Epoch 40/80
# 3/3 [==============================] - 0s 121ms/step - loss: 0.0222 - val_loss: 0.0220
# Epoch 41/80
# 3/3 [==============================] - 0s 148ms/step - loss: 0.0221 - val_loss: 0.0203
# Epoch 42/80
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0223 - val_loss: 0.0205
# Epoch 43/80
# 3/3 [==============================] - 0s 148ms/step - loss: 0.0228 - val_loss: 0.0205
# Epoch 44/80
# 3/3 [==============================] - 0s 140ms/step - loss: 0.0222 - val_loss: 0.0202
# Epoch 45/80
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0215 - val_loss: 0.0233
# Epoch 46/80
# 3/3 [==============================] - 0s 141ms/step - loss: 0.0210 - val_loss: 0.0201
# Epoch 47/80
# 3/3 [==============================] - 0s 131ms/step - loss: 0.0224 - val_loss: 0.0233
# Epoch 48/80
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0219 - val_loss: 0.0205
# Epoch 49/80
# 3/3 [==============================] - 0s 133ms/step - loss: 0.0228 - val_loss: 0.0202
# Epoch 50/80
# 3/3 [==============================] - 0s 141ms/step - loss: 0.0218 - val_loss: 0.0200
# Epoch 51/80
# 3/3 [==============================] - 0s 121ms/step - loss: 0.0215 - val_loss: 0.0199
# Epoch 52/80
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0214 - val_loss: 0.0202
# Epoch 53/80
# 3/3 [==============================] - 0s 134ms/step - loss: 0.0218 - val_loss: 0.0195
# Epoch 54/80
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0218 - val_loss: 0.0206
# Epoch 55/80
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0214 - val_loss: 0.0218
# Epoch 56/80
# 3/3 [==============================] - 0s 140ms/step - loss: 0.0232 - val_loss: 0.0195
# Epoch 57/80
# 3/3 [==============================] - 0s 132ms/step - loss: 0.0222 - val_loss: 0.0208
# Epoch 58/80
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0226 - val_loss: 0.0193
# Epoch 59/80
# 3/3 [==============================] - 0s 136ms/step - loss: 0.0203 - val_loss: 0.0236
# Epoch 60/80
# 3/3 [==============================] - 0s 126ms/step - loss: 0.0205 - val_loss: 0.0191
# Epoch 61/80
# 3/3 [==============================] - 0s 144ms/step - loss: 0.0217 - val_loss: 0.0227
# Epoch 62/80
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0214 - val_loss: 0.0194
# Epoch 63/80
# 3/3 [==============================] - 0s 134ms/step - loss: 0.0235 - val_loss: 0.0206
# Epoch 64/80
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0209 - val_loss: 0.0236
# Epoch 65/80
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0218 - val_loss: 0.0195
# Epoch 66/80
# 3/3 [==============================] - 0s 131ms/step - loss: 0.0210 - val_loss: 0.0233
# Epoch 67/80
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0212 - val_loss: 0.0188
# Epoch 68/80
# 3/3 [==============================] - 0s 134ms/step - loss: 0.0208 - val_loss: 0.0217
# Epoch 69/80
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0210 - val_loss: 0.0212
# Epoch 70/80
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0207 - val_loss: 0.0193
# Epoch 71/80
# 3/3 [==============================] - 0s 134ms/step - loss: 0.0206 - val_loss: 0.0201
# Epoch 72/80
# 3/3 [==============================] - 0s 145ms/step - loss: 0.0210 - val_loss: 0.0187
# Epoch 73/80
# 3/3 [==============================] - 0s 140ms/step - loss: 0.0218 - val_loss: 0.0209
# Epoch 74/80
# 3/3 [==============================] - 0s 139ms/step - loss: 0.0223 - val_loss: 0.0203
# Epoch 75/80
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0227 - val_loss: 0.0195
# Epoch 76/80
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0221 - val_loss: 0.0202
# Epoch 77/80
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0229 - val_loss: 0.0184
# Epoch 78/80
# 3/3 [==============================] - 0s 135ms/step - loss: 0.0227 - val_loss: 0.0238
# Epoch 79/80
# 3/3 [==============================] - 0s 144ms/step - loss: 0.0255 - val_loss: 0.0222
# Epoch 80/80
# 3/3 [==============================] - 0s 136ms/step - loss: 0.0249 - val_loss: 0.0189

# %%
# Visualisasi loss per iterasi
import matplotlib.pyplot as plt
plt.plot(train.history['loss'], label='loss')
plt.plot(train.history['val_loss'], label='val loss')
plt.legend()

# %%
# Forecasr menggunakan true target

validation_target = Y[-N//2:]
validation_predictions = []

#index pertama input validasi
i = -N//2

while len(validation_predictions) < len(validation_target):
    p = model.predict(X[i].reshape(1, -1))[0, 0] # 1x1 array = scalar
    i += 1
    
    #update prediksi
    validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %%
# Forecasr nilai masa depan (prediksi masa depan)

validation_target = Y[-N//2:]
validation_predictions = []

# input training terakhir
last_x = X[-N//2] #1 Dimensi array dari panjang T

while len(validation_predictions) < len(validation_target):
    p = model.predict(last_x.reshape(1, -1))[0,0] # 1X1 ARRAY = scalar
    
    #update prediksi
    validation_predictions.append(p)
    
    #membuat input baru
    last_x = np.roll(last_x, -1)
    last_x[-1] = p

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()
